# %% [markdown]
# <a href="https://colab.research.google.com/github/SahasHimsara/LUNA-AI/blob/master_feature_1/Luna_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy sklearn nltk torch transformers
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import classification_report
import torch
from transformers import BertTokenizer, BertForSequenceClassification
from torch.utils.data import DataLoader, Dataset

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
data = [


                ("I'm feeling really down today.", "sad"),
                ("I just got some good news!", "happy"),
                ("I'm feeling really anxious.", "anxious"),
                ("I’m excited about this weekend!", "excited"),
                ("I'm so stressed out with work.", "stressed"),
                ("I’m having a great day!", "happy"),
                ("I'm feeling lonely lately.", "lonely"),
                ("I can’t stop thinking about the past.", "sad"),
                ("I’m overwhelmed with everything.", "stressed"),
                ("I’m in a really good mood today!", "happy"),
                ("Good morning  ", "neutral"),
                (" Good morning ", "neutral"),
                ("Hi ", "neutral"),
                ("Hiiiiiiiii", "excited"),
                ("How are you?", "neutral"),
                ("I’m doing great, thanks for asking!", "happy"),
                ("Hello!", "neutral"),
                ("Hey there!", "neutral"),
                ("What’s up?", "neutral"),
                ("Not much, how about you?", "neutral"),
                ("Good afternoon", "neutral"),
                ("Hope your day’s going well!", "neutral"),
                ("Morning!", "neutral"),
                ("Rise and shine!", "neutral"),
                ("How’s it going?", "neutral"),
                ("All good, how about you?", "neutral"),
                ("Hey!", "neutral"),
                ("Yo!", "neutral"),
                ("Hi there", "neutral"),
                ("Hello, how’s your day?", "neutral"),
                ("What’s happening?", "neutral"),
                ("Just chilling, how about you?", "neutral"),
                ("Good night", "neutral"),
                ("Sweet dreams!", "neutral"),
                ("Good evening", "neutral"),
                ("Good to see you!", "neutral"),
                ("What’s new?", "neutral"),
                ("Not much, just relaxing!", "neutral"),
                ("Howdy!", "neutral"),
                ("Hey, how’s everything?", "neutral"),
                ("How’s your day?", "neutral"),
                ("Pretty good, thanks for asking!", "happy"),
                ("Yo!", "neutral"),
                ("What’s up, my friend?", "neutral"),
                ("Hiya!", "neutral"),
                ("Hello there!", "neutral"),
                ("Greetings!", "neutral"),
                ("Salutations!", "neutral"),
                ("Long time no see!", "neutral"),
                ("I know, it’s been a while!", "neutral"),
                ("What’s going on?", "neutral"),
                ("Not much, just enjoying the day!", "neutral"),
                ("Morning sunshine!", "neutral"),
                ("Good morning, starshine!", "neutral"),
                ("I'm feeling really down today.", "sad"),
                ("I just got some good news!", "happy"),
                ("I'm feeling really anxious.", "anxious"),
                ("I’m excited about this weekend!", "excited"),
                ("I'm so stressed out with work.", "stressed"),
                ("I’m having a great day!", "happy"),
                ("I'm feeling lonely lately.", "lonely"),
                ("I can’t stop thinking about the past.", "sad"),
                ("I’m overwhelmed with everything.", "stressed"),
                ("I’m in a really good mood today!", "happy"),
                ("I feel so tired today.", "tired"),
                ("I’m really proud of what I accomplished today.", "proud"),
                ("I’m feeling a bit lost.", "lost"),
                ("I’m really excited for the holidays.", "excited"),
                ("I feel like everything is going wrong.", "sad"),
                ("I just need some time to myself.", "neutral"),
                ("I’m really grateful for today.", "grateful"),
                ("I’m nervous about the future.", "anxious"),
                ("I’m feeling so overwhelmed by everything.", "stressed"),
                ("I’m feeling great today!", "happy"),
                ("I’ve been feeling really disconnected lately.", "lonely"),
                ("I’m worried about tomorrow.", "anxious"),
                ("I’m feeling really motivated right now!", "motivated"),
                ("I’ve been so busy lately.", "stressed"),
                ("I feel like everything is in chaos.", "stressed"),
                ("I’m feeling a little discouraged.", "sad"),
                ("I’m feeling hopeful about the future.", "hopeful"),
                ("I’m feeling really happy today!", "happy"),
                ("I feel like I’m stuck in a rut.", "stuck"),
                ("I’m feeling so grateful today.", "grateful"),
                ("I’m really proud of myself for making progress.", "proud"),
                ("I’m really nervous about this presentation.", "nervous"),
                ("I’m feeling very positive about everything.", "positive"),
                ("I’m feeling a bit confused.", "confused"),
                ("I’m feeling like I need a break.", "tired"),
                ("I’m really upset about what happened.", "upset"),
                ("I’m feeling so much better today.", "relieved"),
                ("I’m feeling a little anxious about the future.", "anxious"),
                ("I’m feeling so motivated to work out.", "motivated"),
                ("I’m feeling a bit overwhelmed by everything.", "stressed"),
                ("I’m really proud of what I’ve achieved so far.", "proud"),
                ("I feel really calm today.", "calm"),
                ("I’m feeling really down about this situation.", "sad"),
                ("I feel like things are finally turning around.", "hopeful"),
                ("I’m feeling overwhelmed with work.", "stressed"),
                ("I’m feeling pretty excited right now.", "excited"),
                ("I’m feeling really tired.", "tired"),
                ("I feel like I’m in a slump.", "stuck"),
                ("I’m feeling so much anxiety right now.", "anxious"),
                ("I’m feeling a bit better today.", "relieved"),
                ("I’m feeling really proud of myself today.", "proud"),
                ("I’m feeling a little lonely.", "lonely"),
                ("I’m so excited about this opportunity.", "excited"),
                ("I’m feeling like I can conquer anything right now.", "motivated"),
                ("I’m feeling really nervous about the exam.", "nervous"),
                ("I’m feeling really grateful today.", "grateful"),
                ("I’m feeling like I’ve made some progress.", "proud"),
                ("I feel really connected to myself today.", "calm"),
                ("I’m feeling really sad right now.", "sad"),
                ("I’m feeling so stressed out.", "stressed"),
                ("I’m feeling like I’m getting stronger.", "motivated"),
                ("I’m feeling a little bit unsure about things.", "uncertain"),
                ("I’m feeling really happy today.", "happy"),
                ("I’m feeling a bit stuck in life.", "stuck"),
                ("I’m feeling like I need a change.", "uncertain"),
                ("I’m feeling really good today.", "happy"),
                ("I’m feeling a little overwhelmed.", "stressed"),
                ("I’m feeling pretty motivated.", "motivated"),
                ("I’m feeling really anxious about everything.", "anxious"),
                ("I’m feeling really relaxed.", "calm"),
                ("I’m feeling a little sad today.", "sad"),
                ("I’m feeling really excited for the future.", "excited"),
                ("I’m feeling so thankful for today.", "grateful"),
                ("I’m feeling pretty good today.", "happy"),
                ("I’m feeling really calm today.", "calm"),
                ("I’m feeling so much more confident.", "confident"),
                ("I’m feeling really stressed about work.", "stressed"),
                ("I’m feeling like I need a break.", "tired"),
                ("I’m feeling a little uneasy.", "anxious"),
                ("I’m feeling pretty good today.", "happy"),
                ("I’m feeling really optimistic.", "hopeful"),
                ("I’m feeling a bit tired.", "tired"),
                ("I’m feeling really energized!", "energized"),
                ("I’m feeling really proud of what I’ve done today.", "proud"),
                ("I’m feeling so happy today!", "happy"),
                ("I'm feeling really down today.", "sad"),
                ("I just got some good news!", "happy"),
                ("I'm feeling really anxious.", "anxious"),
                ("I’m excited about this weekend!", "excited"),
                ("I'm so stressed out with work.", "stressed"),
                ("I'm feeling lonely lately.", "lonely"),
                ("I feel so tired today.", "sad"),
                ("I’m really happy for today!", "happy"),
                ("I'm nervous about tomorrow.", "anxious"),
                ("I can't wait for the weekend!", "excited"),
                ("Work is stressing me out today.", "stressed"),
                ("I've been feeling really disconnected lately.", "lonely"),
                ("I’m feeling like everything is going wrong.", "sad"),
                ("I’m in a really good mood today!", "happy"),
                ("I'm feeling so much anxiety right now.", "anxious"),
                ("I’m looking forward to this vacation!", "excited"),
                ("Everything is so overwhelming right now.", "stressed"),
                ("I’m feeling really alone today.", "lonely"),
                ("I’m feeling pretty sad about this situation.", "sad"),
                ("I just got a promotion at work!", "happy"),
                ("I’m anxious about what’s coming next.", "anxious"),
                ("I’m super excited about this new project.", "excited"),
                ("I’ve got a lot on my plate today.", "stressed"),
                ("I feel really isolated today.", "lonely"),
                ("I feel down about the way things turned out.", "sad"),
                ("I’m so happy to be spending time with friends!", "happy"),
                ("I'm feeling a bit uneasy about the presentation.", "anxious"),
                ("I’m looking forward to catching up with everyone this weekend!", "excited"),
                ("I’m stressed about all the deadlines.", "stressed"),
                ("I’ve been feeling really lonely lately.", "lonely"),
                ("I'm feeling so low today.", "sad"),
                ("I’m so happy about this opportunity!", "happy"),
                ("I’m feeling nervous about my interview.", "anxious"),
                ("I’m so excited to go on this trip!", "excited"),
                ("I’ve been so stressed out recently.", "stressed"),
                ("I feel like no one understands me.", "lonely"),
                ("I just can’t shake this sad feeling.", "sad"),
                ("I’m feeling great today!", "happy"),
                ("I’m anxious about the future.", "anxious"),
                ("I can’t wait for the new movie to come out!", "excited"),
                ("I’ve been working nonstop and it’s wearing me out.", "stressed"),
                ("I feel disconnected from everyone.", "lonely"),
                ("I feel like everything is falling apart.", "sad"),
                ("I’m so happy for all the amazing things happening in my life.", "happy"),
                ("I’m feeling a bit anxious about the exam.", "anxious"),
                ("I’m thrilled about the new job!", "excited"),
                ("I feel completely drained from work.", "stressed"),
                ("I’m feeling pretty lonely right now.", "lonely"),
                ("I just want to cry today.", "sad"),
                ("I’m so happy that I can finally relax!", "happy"),
                ("I’m feeling really nervous about this presentation.", "anxious"),
                ("I’m really excited for the concert tonight!", "excited"),
                ("I’m overwhelmed with tasks at work.", "stressed"),
                ("I feel like I don’t have anyone to talk to.", "lonely"),
                ("I’m feeling really down after that conversation.", "sad"),
                ("I’m so happy to be home!", "happy"),
                ("I’m feeling nervous about the upcoming exam.", "anxious"),
                ("I’m so excited to see everyone this weekend!", "excited"),
                ("The workload is really stressing me out.", "stressed"),
                ("I feel like I’m all alone.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy I got to see my friends!", "happy"),
                ("I’m anxious about meeting new people.", "anxious"),
                ("I’m really excited about the holidays!", "excited"),
                ("I’m feeling so stressed out with everything happening at work.", "stressed"),
                ("I’ve been feeling isolated lately.", "lonely"),
                ("I feel so hopeless today.", "sad"),
                ("I’m so happy I’ve reached this milestone!", "happy"),
                ("I’m anxious about starting this new chapter.", "anxious"),
                ("I’m excited to try something new today.", "excited"),
                ("I’ve got too much to do and not enough time.", "stressed"),
                ("I’ve been feeling so alone recently.", "lonely"),
                ("I feel like things are never going to get better.", "sad"),
                ("I’m feeling so blessed and happy today.", "happy"),
                ("I’m feeling anxious about the future.", "anxious"),
                ("I’m really excited for the upcoming event!", "excited"),
                ("I’m completely exhausted and stressed out.", "stressed"),
                ("I feel like no one really cares about me.", "lonely"),
                ("I just want to be alone today.", "sad"),
                ("I’m so happy to have made it through this week!", "happy"),
                ("I feel nervous about taking this next step.", "anxious"),
                ("I’m really excited to go on vacation!", "excited"),
                ("I’ve been feeling so stressed with everything on my plate.", "stressed"),
                ("I’m feeling a little lonely today.", "lonely"),
                ("I’m really down after hearing that news.", "sad"),
                ("I’m so happy for all the good things happening!", "happy"),
                ("I’m anxious about what comes next.", "anxious"),
                ("I’m feeling so excited for the weekend.", "excited"),
                ("I’m feeling really stressed with work deadlines.", "stressed"),
                ("I’ve been feeling so lonely and isolated.", "lonely"),
                ("I feel heartbroken today.", "sad"),
                ("I’m so happy to be spending time with family.", "happy"),
                ("I’m anxious about how things will turn out.", "anxious"),
                ("I’m really excited for the future.", "excited"),
                ("I’m overwhelmed by everything happening right now.", "stressed"),
                ("I feel like I’m on my own today.", "lonely"),
                ("I feel so down about this situation.", "sad"),
                ("I’m so happy to be surrounded by positive energy!", "happy"),
                ("I’m feeling really anxious about the presentation.", "anxious"),
                ("I’m so excited for the big day tomorrow!", "excited"),
                ("I’ve been feeling stressed out all week.", "stressed"),
                ("I’m feeling really alone today.", "lonely"),
                ("I’m feeling a little sad right now.", "sad"),
                ("I’m so happy to be alive!", "happy"),
                ("I’m anxious about the changes coming up.", "anxious"),
                ("I’m really excited about starting my new project.", "excited"),
                ("I’m feeling so overwhelmed with everything.", "stressed"),
                ("I feel lonely and disconnected from others.", "lonely"),
                ("I’m feeling down about the way things are going.", "sad"),
                ("I’m feeling so happy to be with my loved ones.", "happy"),
                ("I’m anxious about the unknown.", "anxious"),
                ("I’m really excited to start something new.", "excited"),
                ("I’m stressing over all the work I have to do.", "stressed"),
                ("I’m feeling lonely today.", "lonely"),
                ("I’m feeling really sad after that conversation.", "sad"),
                ("I’m so happy to be part of this team!", "happy"),
                ("I’m feeling anxious about my performance.", "anxious"),
                ("I’m so excited for the concert tonight!", "excited"),
                ("I’m feeling really stressed with everything happening at work.", "stressed"),
                ("I feel disconnected from everyone today.", "lonely"),
                ("I’m feeling really down after what happened.", "sad"),
                ("I’m so happy to have this opportunity.", "happy"),
                ("I’m feeling a bit anxious about the future.", "anxious"),
                ("I’m excited about the possibilities ahead.", "excited"),
                ("I’m feeling stressed about all the responsibilities.", "stressed"),
                ("I feel lonely in this crowd.", "lonely"),
                ("I’m feeling so sad about the situation.", "sad"),
                ("I’m so happy that I reached my goal!", "happy"),
                ("I’m anxious about everything that’s happening.", "anxious"),
                ("I’m really excited for the weekend getaway.", "excited"),
                ("I’m feeling so stressed with everything piling up.", "stressed"),
                ("I feel like I’m the only one going through this.", "lonely"),
                ("I feel so down about what happened.", "sad"),
                ("I’m so happy for everything I’ve achieved!", "happy"),
                ("I’m feeling nervous about this challenge.", "anxious"),
                ("I’m excited about this new adventure.", "excited"),
                ("I feel overwhelmed by all the tasks.", "stressed"),
                ("I’ve been feeling really lonely lately.", "lonely"),
                ("I’m feeling so sad today.", "sad"),
                ("I’m so happy to be here with you.", "happy"),
                ("I’m anxious about making the right decision.", "anxious"),
                ("I’m so excited to see what happens next.", "excited"),
                ("I’m really stressed with all these commitments.", "stressed"),
                ("I feel isolated from everyone.", "lonely"),
                ("I feel heartbroken today.", "sad"),
                ("I’m so happy to be in this place right now.", "happy"),
                ("I’m feeling really anxious about everything.", "anxious"),
                ("I’m excited to be starting a new chapter.", "excited"),
                ("I’ve been so stressed out about work lately.", "stressed"),
                ("I’m feeling lonely without my friends.", "lonely"),
                ("I’m feeling so low today.", "sad"),
                ("I’m happy I’ve got everything in place.", "happy"),
                ("I feel anxious about the uncertain future.", "anxious"),
                ("I’m excited for what’s coming next.", "excited"),
                ("I’m so stressed about the workload.", "stressed"),
                ("I feel so disconnected from the world right now.", "lonely"),
                ("I feel so sad after what happened.", "sad"),
                ("I’m so happy to be surrounded by good people.", "happy"),
                ("I’m feeling anxious about the upcoming event.", "anxious"),
                ("I’m really excited for the journey ahead.", "excited"),
                ("I’ve been feeling really stressed out with everything.", "stressed"),
                ("I feel so lonely theseeryone!", "happy"),
                ("I’m anxious about meeting new people.", "anxious"),
                ("I’m so excited to begin this adventure.", "excited"),
                ("I feel so stressed with everything happening right now.", "stressed"),
                ("I feel like no one is there for me.", "lonely"),
                ("I’m feeling sad about everything.", "sad"),
                ("I’m happy with how things are going.", "happy"),
                ("I’m anxious about the upcoming changes.", "anxious"),
                ("I’m excited for the challenge ahead.", "excited"),
                ("I’m so stressed with my responsibilities.", "stressed"),
                ("I’ve been feeling lonely lately.", "lonely"),
                ("I’m feeling so sad after what happened.", "sad"),
                ("I’m really happy with the way things are going.", "happy"),
                ("I’m feeling anxious about everything that’s coming up.", "anxious"),
                ("I’m so excited to start this new project.", "excited"),
                ("I’m so stressed with everything that’s going on.", "stressed"),
                ("I feel so lonely these days.", "lonely"),
                ("I feel sad that it’s over.", "sad"),
                ("I’m so happy that I’m finally here.", "happy"),
                ("I’m anxious about how things will turn out.", "anxious"),
                ("I’m excited for the things ahead.", "excited"),
                ("I feel so stressed with all my responsibilities.", "stressed"),
                ("I feel like I’m alone in this.", "lonely"),
                ("I’m feeling so sad today.", "sad"),
                ("I’m happy that things are going well.", "happy"),
                ("I’m anxious about how things will go.", "anxious"),
                ("I’m really excited for this new journey.", "excited"),
                ("I’m stressed about everything I need to get done.", "stressed"),
                ("I feel so lonely without anyone to talk to.", "lonely"),
                ("I feel really down today.", "sad"),
                ("I’m so happy about everything going on.", "happy"),
                ("I feel nervous about what’s next.", "anxious"),
                ("I’m really excited for the upcoming adventure.", "excited"),
                ("I'm feeling so down today.", "sad"),
                ("I just got some amazing news!", "happy"),
                ("I'm feeling nervous about the upcoming test.", "anxious"),
                ("I can't wait to see the concert tonight!", "excited"),
                ("I’m feeling overwhelmed with work.", "stressed"),
                ("I feel so lonely right now.", "lonely"),
                ("I’m feeling really sad about everything.", "sad"),
                ("I’m so happy about the promotion I received!", "happy"),
                ("I’m anxious about how the meeting will go.", "anxious"),
                ("I’m excited to travel this weekend!", "excited"),
                ("I'm struggling with a lot of tasks right now.", "stressed"),
                ("I feel like no one understands me.", "lonely"),
                ("I feel really heartbroken today.", "sad"),
                ("I’m so happy with my new home!", "happy"),
                ("I’m anxious about my performance in the presentation.", "anxious"),
                ("I’m so excited about the upcoming vacation!", "excited"),
                ("I have so many things to do, and it's stressing me out.", "stressed"),
                ("I feel completely alone today.", "lonely"),
                ("I feel like everything is falling apart.", "sad"),
                ("I’m so happy that I get to spend time with my family!", "happy"),
                ("I’m feeling a bit uneasy about the new changes.", "anxious"),
                ("I’m so excited for the upcoming event!", "excited"),
                ("I feel like I’m drowning in work.", "stressed"),
                ("I feel so isolated from everyone.", "lonely"),
                ("I'm feeling really low today.", "sad"),
                ("I’m so happy to have made it through the week!", "happy"),
                ("I’m anxious about the future and what it holds.", "anxious"),
                ("I can’t wait for this weekend's adventure!", "excited"),
                ("I feel like there's just too much on my plate.", "stressed"),
                ("I feel so disconnected from the people around me.", "lonely"),
                ("I’m feeling really sad after that argument.", "sad"),
                ("I’m so happy I got to see my friends this weekend!", "happy"),
                ("I'm feeling quite anxious about the upcoming exam.", "anxious"),
                ("I’m excited for the new project to begin!", "excited"),
                ("I’m stressed with all the deadlines approaching.", "stressed"),
                ("I feel like I'm invisible to everyone around me.", "lonely"),
                ("I’m feeling so sad about how things ended.", "sad"),
                ("I’m so happy to finally relax this evening.", "happy"),
                ("I feel really nervous about my job interview.", "anxious"),
                ("I’m so excited for the new year ahead!", "excited"),
                ("I'm overwhelmed by everything I have to do.", "stressed"),
                ("I feel so alone lately.", "lonely"),
                ("I’m feeling down after that tough conversation.", "sad"),
                ("I’m so happy to be able to unwind after work.", "happy"),
                ("I feel anxious about the changes coming in my life.", "anxious"),
                ("I’m really excited to meet everyone this weekend!", "excited"),
                ("I’ve got a lot of stress with work piling up.", "stressed"),
                ("I feel like I don’t have anyone to talk to right now.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy I finally got the job I wanted!", "happy"),
                ("I’m feeling anxious about the new responsibilities.", "anxious"),
                ("I’m really excited for the weekend getaway.", "excited"),
                ("I’m stressed because I can’t keep up with all my tasks.", "stressed"),
                ("I feel so lonely in this big crowd.", "lonely"),
                ("I feel so sad about the way things turned out.", "sad"),
                ("I’m so happy for the opportunity to travel.", "happy"),
                ("I feel anxious about making the right decisions.", "anxious"),
                ("I’m excited to start my new adventure tomorrow!", "excited"),
                ("I feel so stressed with everything on my mind.", "stressed"),
                ("I feel lonely even when I'm around others.", "lonely"),
                ("I'm feeling really sad today.", "sad"),
                ("I’m so happy that everything is going so well.", "happy"),
                ("I’m feeling anxious about the meeting tomorrow.", "anxious"),
                ("I’m excited for the chance to explore new things!", "excited"),
                ("I'm really stressed with all these assignments.", "stressed"),
                ("I feel like I'm alone in this world.", "lonely"),
                ("I’m feeling down about my performance.", "sad"),
                ("I’m so happy about all the progress I’ve made.", "happy"),
                ("I’m anxious about what the future holds.", "anxious"),
                ("I can’t wait for this weekend's trip!", "excited"),
                ("I feel stressed with the pressure at work.", "stressed"),
                ("I feel so alone right now.", "lonely"),
                ("I'm feeling really sad after hearing the news.", "sad"),
                ("I’m so happy to be with my loved ones.", "happy"),
                ("I’m anxious about my upcoming presentation.", "anxious"),
                ("I’m really excited about the new movie release.", "excited"),
                ("I feel overwhelmed with everything I need to do.", "stressed"),
                ("I feel so lonely these days.", "lonely"),
                ("I’m feeling sad because things didn’t go as planned.", "sad"),
                ("I’m so happy to be here with friends.", "happy"),
                ("I’m anxious about making a good impression.", "anxious"),
                ("I’m so excited for the weekend getaway!", "excited"),
                ("I’m feeling so stressed with all the work I have to finish.", "stressed"),
                ("I feel like I’m not connecting with anyone.", "lonely"),
                ("I feel so sad about the things I’ve lost.", "sad"),
                ("I’m so happy that everything worked out in the end.", "happy"),
                ("I feel anxious about the unknown future.", "anxious"),
                ("I’m excited to see how everything turns out.", "excited"),
                ("I feel so stressed out with everything piling up.", "stressed"),
                ("I feel so lonely these days.", "lonely"),
                ("I'm feeling so sad after that argument.", "sad"),
                ("I’m so happy to be with people who care about me.", "happy"),
                ("I’m feeling anxious about the big day.", "anxious"),
                ("I’m really excited to start this new chapter in life.", "excited"),
                ("I feel really stressed with all the things I have to do.", "stressed"),
                ("I feel so disconnected from everyone.", "lonely"),
                ("I’m feeling so sad about what happened.", "sad"),
                ("I’m so happy to have everything fall into place.", "happy"),
                ("I’m anxious about how things are going to turn out.", "anxious"),
                ("I’m so excited for the new opportunities ahead.", "excited"),
                ("I’m feeling overwhelmed with the amount of work I have.", "stressed"),
                ("I feel lonely without my friends around.", "lonely"),
                ("I’m feeling really sad today.", "sad"),
                ("I’m so happy that I can relax after all that work.", "happy"),
                ("I feel nervous about how everything will turn out.", "anxious"),
                ("I’m so excited to start this new journey.", "excited"),
                ("I’m really stressed with the heavy workload.", "stressed"),
                ("I feel so lonely without any support.", "lonely"),
                ("I'm feeling really sad about how everything went wrong.", "sad"),
                ("I’m so happy I was able to accomplish this task.", "happy"),
                ("I feel anxious about the things I have to handle.", "anxious"),
                ("I’m excited about the upcoming holidays.", "excited"),
                ("I feel so stressed with all these deadlines.", "stressed"),
                ("I feel like I don’t have anyone to talk to right now.", "lonely"),
                ("I’m feeling really down about this situation.", "sad"),
                ("I’m so happy about the chance to do something I love.", "happy"),
                ("I’m feeling anxious about the next big step.", "anxious"),
                ("I’m so excited about the weekend trip.", "excited"),
                ("I’m feeling really stressed with all the pressure.", "stressed"),
                ("I feel so lonely today.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy to finally take a break.", "happy"),
                ("I’m anxious about the future and all the changes.", "anxious"),
                ("I’m really excited about what’s coming next.", "excited"),
                ("I’m feeling so stressed from all the tasks at hand.", "stressed"),
                ("I feel disconnected from everyone.", "lonely"),
                ("I’m feeling really low today.", "sad"),
                ("I’m so happy to be in such a great place in life.", "happy"),
                ("I’m feeling anxious about the upcoming project.", "anxious"),
                ("I’m really excited to start my new job.", "excited"),
                ("I’m stressed with the tight deadlines.", "stressed"),
                ("I feel lonely without anyone to share my thoughts with.", "lonely"),
                ("I’m feeling so sad about everything going wrong.", "sad"),
                ("I’m so happy to be surrounded by positivity.", "happy"),
                ("I’m anxious about the changes happening in my life.", "anxious"),
                ("I’m excited for all the new experiences ahead.", "excited"),
                ("I feel so stressed with the amount of work I have.", "stressed"),
                ("I feel lonely even in a crowd.", "lonely"),
                ("I feel so lost today.", "sad"),
                ("I’m really happy with how things turned out.", "happy"),
                ("I’m feeling anxious about meeting new people.", "anxious"),
                ("I can’t wait to see what happens next!", "excited"),
                ("I’m really stressed about everything going on at work.", "stressed"),
                ("I feel completely alone right now.", "lonely"),
                ("I’m so sad that it’s all over.", "sad"),
                ("I’m so happy to finally be home.", "happy"),
                ("I’m anxious about not having enough time to finish everything.", "anxious"),
                ("I’m really excited about the road trip this weekend!", "excited"),
                ("I feel like there’s too much to handle right now.", "stressed"),
                ("I feel so alone even though I’m surrounded by people.", "lonely"),
                ("I’m feeling really sad about everything that happened.", "sad"),
                ("I’m so happy I got to spend time with my friends.", "happy"),
                ("I’m anxious about how things are going to play out.", "anxious"),
                ("I’m so excited to see my favorite band perform.", "excited"),
                ("I feel so stressed with all the demands at work.", "stressed"),
                ("I feel like I’m fading into the background.", "lonely"),
                ("I’m really sad that I missed the event.", "sad"),
                ("I’m so happy to have made it through another week.", "happy"),
                ("I’m anxious about what’s going to happen next.", "anxious"),
                ("I’m so excited for the concert tomorrow!", "excited"),
                ("I feel like everything is coming at me all at once.", "stressed"),
                ("I feel so isolated from everyone.", "lonely"),
                ("I’m feeling really sad after that argument.", "sad"),
                ("I’m so happy that I’ve been able to stay focused.", "happy"),
                ("I feel anxious about the upcoming changes at work.", "anxious"),
                ("I’m excited to go on this new adventure!", "excited"),
                ("I feel so stressed about all the decisions I have to make.", "stressed"),
                ("I feel like no one truly cares about me.", "lonely"),
                ("I feel like nothing is going right.", "sad"),
                ("I’m so happy to be spending the holidays with my family.", "happy"),
                ("I’m anxious about whether I’ll be able to meet the expectations.", "anxious"),
                ("I’m excited about all the new things I’m about to learn!", "excited"),
                ("I feel really stressed with everything piling up.", "stressed"),
                ("I feel so lonely even when I’m with people.", "lonely"),
                ("I’m feeling really sad about my situation.", "sad"),
                ("I’m so happy to be able to spend time with my friends again.", "happy"),
                ("I’m anxious about how my presentation will go.", "anxious"),
                ("I’m so excited for the new adventure ahead.", "excited"),
                ("I’m feeling stressed because I’m falling behind.", "stressed"),
                ("I feel so alone right now.", "lonely"),
                ("I’m feeling sad that I can’t do more.", "sad"),
                ("I’m so happy to finally achieve my goals.", "happy"),
                ("I’m feeling anxious about the changes in my life.", "anxious"),
                ("I’m excited for all the fun activities planned this weekend!", "excited"),
                ("I feel so stressed by everything going on around me.", "stressed"),
                ("I feel like I’m being ignored.", "lonely"),
                ("I’m feeling down because everything feels so difficult.", "sad"),
                ("I’m so happy to have made some positive changes in my life.", "happy"),
                ("I’m anxious about the decisions I need to make.", "anxious"),
                ("I’m so excited to see what the future holds.", "excited"),
                ("I feel overwhelmed with the things I have to do.", "stressed"),
                ("I feel completely alone even when I’m surrounded by people.", "lonely"),
                ("I’m feeling so sad that everything is falling apart.", "sad"),
                ("I’m so happy I finally got to do something I love.", "happy"),
                ("I’m anxious about how people will judge me.", "anxious"),
                ("I’m really excited to try something new today.", "excited"),
                ("I’m feeling so stressed with everything on my plate.", "stressed"),
                ("I feel disconnected from everyone around me.", "lonely"),
                ("I’m feeling so down today.", "sad"),
                ("I’m so happy to be able to relax for a bit.", "happy"),
                ("I feel anxious about how I’m performing.", "anxious"),
                ("I’m so excited for the weekend plans.", "excited"),
                ("I’m feeling stressed because I have too much to do.", "stressed"),
                ("I feel so lonely with no one to talk to.", "lonely"),
                ("I’m feeling really sad about everything happening.", "sad"),
                ("I’m so happy to be with my loved ones.", "happy"),
                ("I’m anxious about not living up to expectations.", "anxious"),
                ("I’m excited to finally take a break.", "excited"),
                ("I feel stressed because I’m running out of time.", "stressed"),
                ("I feel like I have no real connections with anyone.", "lonely"),
                ("I’m feeling really low today.", "sad"),
                ("I’m so happy to be in a better place.", "happy"),
                ("I feel anxious about the pressure to succeed.", "anxious"),
                ("I’m so excited to get started on the new project.", "excited"),
                ("I feel stressed with everything piling up at work.", "stressed"),
                ("I feel like I don’t belong anywhere.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy I made it through today.", "happy"),
                ("I’m anxious about how everything will unfold.", "anxious"),
                ("I’m excited to see what happens next.", "excited"),
                ("I feel so stressed with all these responsibilities.", "stressed"),
                ("I feel so alone, even in a room full of people.", "lonely"),
                ("I’m feeling so sad today.", "sad"),
                ("I’m so happy to be able to help others.", "happy"),
                ("I’m anxious about the upcoming presentation.", "anxious"),
                ("I’m so excited for the new beginnings.", "excited"),
                ("I feel stressed because everything is so urgent.", "stressed"),
                ("I feel like no one cares about me.", "lonely"),
                ("I’m feeling really down about everything.", "sad"),
                ("I’m so happy with how much progress I’ve made.", "happy"),
                ("I’m anxious about how people will respond to me.", "anxious"),
                ("I’m excited for the surprises that await.", "excited"),
                ("I feel really stressed because I’m constantly working.", "stressed"),
                ("I feel so isolated, even with others around me.", "lonely"),
                ("I’m feeling sad because I feel out of control.", "sad"),
                ("I’m so happy about my accomplishments today.", "happy"),
                ("I feel anxious about the future.", "anxious"),
                ("I’m really excited for the upcoming trip.", "excited"),
                ("I feel stressed about all the things I have to manage.", "stressed"),
                ("I feel lonely without anyone by my side.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy about how things are going.", "happy"),
                ("I’m anxious about making the wrong choices.", "anxious"),
                ("I’m so excited to start something new.", "excited"),
                ("I feel so stressed by the pressure of deadlines.", "stressed"),
                ("I feel completely alone right now.", "lonely"),
                ("I’m feeling down about everything that’s happening.", "sad"),
                ("I’m so happy to have good news.", "happy"),
                ("I’m anxious about everything I have to do.", "anxious"),
                ("I’m so excited for the weekend trip.", "excited"),
                ("I feel so stressed trying to meet everyone’s expectations.", "stressed"),
                ("I feel like I have no one to turn to.", "lonely"),
                ("I’m feeling really sad today.", "sad"),
                ("I’m so happy to be in the moment.", "happy"),
                ("I feel anxious about the things I have to face.", "anxious"),
                ("I’m excited for everything that’s coming up.", "excited"),
                ("I feel stressed out by everything I need to do.", "stressed"),
                ("I feel like I don’t belong anywhere.", "lonely"),
                ("I’m feeling really sad after what happened.", "sad"),
                ("I’m so happy about my success.", "happy"),
                ("I feel anxious about not being good enough.", "anxious"),
                ("I’m excited to experience something new.", "excited"),
                ("I feel overwhelmed with the responsibilities.", "stressed"),
                ("I feel so lonely these days.", "lonely"),
                ("I’m feeling sad because things aren’t going well.", "sad"),
                ("I’m so happy I’m able to make a difference.", "happy"),
                ("I feel anxious about my performance in the upcoming exam.", "anxious"),
                ("I’m so excited to start my new project.", "excited"),
                ("I feel stressed by everything going on.", "stressed"),
                ("I feel alone even when I’m with others.", "lonely"),
                ("I’m feeling so down today.", "sad"),
                ("I’m so happy to be done with that task.", "happy"),
                ("I feel anxious about the future.", "anxious"),
                ("I’m really excited to go on vacation soon.", "excited"),
                ("I feel like everything is piling up and I can’t keep up.", "stressed"),
                ("I feel disconnected from everyone around me.", "lonely"),
                ("I’m sad that things didn’t turn out as expected.", "sad"),
                ("I’m so happy that I finally made it!", "happy"),
                ("I feel anxious about the uncertainty ahead.", "anxious"),
                ("I’m excited to try something new.", "excited"),
                ("I feel overwhelmed by all the work I need to do.", "stressed"),
                ("I feel like no one is really there for me.", "lonely"),
                ("I’m feeling sad about how things ended.", "sad"),
                ("I’m so happy to have my family here with me.", "happy"),
                ("I’m anxious about upcoming changes in my life.", "anxious"),
                ("I’m so excited to see everyone at the party tonight!", "excited"),
                ("I feel really stressed with all the deadlines coming up.", "stressed"),
                ("I feel completely alone in this situation.", "lonely"),
                ("I’m feeling sad about everything going wrong.", "sad"),
                ("I’m so happy about how much I’ve grown.", "happy"),
                ("I’m anxious about not doing things correctly.", "anxious"),
                ("I’m excited for the new opportunities ahead!", "excited"),
                ("I feel so stressed with all the responsibilities I have.", "stressed"),
                ("I feel isolated even when I’m surrounded by people.", "lonely"),
                ("I’m feeling so sad about everything happening.", "sad"),
                ("I’m so happy that I reached my goal.", "happy"),
                ("I feel anxious about disappointing others.", "anxious"),
                ("I’m really excited about the new adventure ahead.", "excited"),
                ("I feel stressed about how much is expected of me.", "stressed"),
                ("I feel so lonely even though people are around.", "lonely"),
                ("I’m feeling sad because things aren’t going as planned.", "sad"),
                ("I’m so happy to be back with my friends.", "happy"),
                ("I feel anxious about the unknown.", "anxious"),
                ("I’m excited to start a new chapter in my life.", "excited"),
                ("I feel so stressed trying to meet everyone’s expectations.", "stressed"),
                ("I feel so alone in this big world.", "lonely"),
                ("I’m feeling really sad after that argument.", "sad"),
                ("I’m so happy to be with the people who matter most.", "happy"),
                ("I feel anxious about the future and what it holds.", "anxious"),
                ("I’m so excited for the weekend getaway!", "excited"),
                ("I feel overwhelmed by all the things I need to do.", "stressed"),
                ("I feel disconnected from everyone.", "lonely"),
                ("I’m feeling down because nothing seems to be going right.", "sad"),
                ("I’m so happy to have accomplished my goals.", "happy"),
                ("I feel anxious about how things will turn out.", "anxious"),
                ("I’m really excited for what’s coming next.", "excited"),
                ("I feel stressed about managing everything in my life.", "stressed"),
                ("I feel like I’m invisible to everyone.", "lonely"),
                ("I’m feeling really sad about how everything ended.", "sad"),
                ("I’m so happy to have made a difference.", "happy"),
                ("I’m anxious about all the things I still need to do.", "anxious"),
                ("I’m excited to explore new places!", "excited"),
                ("I feel so stressed by everything going on.", "stressed"),
                ("I feel so lonely with no one to talk to.", "lonely"),
                ("I’m feeling down today.", "sad"),
                ("I’m so happy that things are going well.", "happy"),
                ("I’m anxious about the things that are beyond my control.", "anxious"),
                ("I’m so excited for the fun ahead!", "excited"),
                ("I feel like there’s too much to handle right now.", "stressed"),
                ("I feel isolated and alone even when people are around.", "lonely"),
                ("I’m feeling so sad about how things turned out.", "sad"),
                ("I’m so happy to be in a better place.", "happy"),
                ("I’m anxious about how others will perceive me.", "anxious"),
                ("I’m excited for the new experiences coming my way.", "excited"),
                ("I feel stressed about the constant pressure to perform.", "stressed"),
                ("I feel so alone even when I’m with my closest friends.", "lonely"),
                ("I’m feeling sad about the way things have changed.", "sad"),
                ("I’m so happy to have found a new passion.", "happy"),
                ("I feel anxious about what lies ahead.", "anxious"),
                ("I’m so excited to see where this journey takes me!", "excited"),
                ("I feel stressed with the responsibilities I have to juggle.", "stressed"),
                ("I feel like no one truly understands me.", "lonely"),
                ("I’m feeling really sad about everything that’s happening.", "sad"),
                ("I’m so happy to have a fresh start.", "happy"),
                ("I’m anxious about facing challenges that seem too big.", "anxious"),
                ("I’m so excited to meet new people and explore new things.", "excited"),
                ("I feel stressed because I can’t keep up with everything.", "stressed"),
                ("I feel like no one really sees me.", "lonely"),
                ("I’m feeling down because things aren’t as good as they used to be.", "sad"),
                ("I’m so happy to have had a productive day.", "happy"),
                ("I feel anxious about my ability to meet expectations.", "anxious"),
                ("I’m excited to dive into new projects.", "excited"),
                ("I feel so stressed from trying to balance everything.", "stressed"),
                ("I feel like I’m fading into the background.", "lonely"),
                ("I’m feeling sad because I missed an opportunity.", "sad"),
                ("I’m so happy to be making progress in my life.", "happy"),
                ("I’m anxious about everything I need to accomplish.", "anxious"),
                ("I’m so excited for the surprises ahead!", "excited"),
                ("I feel stressed because I have so many things to do.", "stressed"),
                ("I feel like I’m on my own in this journey.", "lonely"),
                ("I’m feeling really sad today.", "sad"),
                ("I’m so happy I can finally relax.", "happy"),
                ("I feel anxious about taking on too much.", "anxious"),
                ("I’m excited for the weekend to recharge.", "excited"),
                ("I feel stressed because there’s too much pressure.", "stressed"),
                ("I feel like no one really knows me.", "lonely"),
                ("I’m feeling sad that I’ve let people down.", "sad"),
                ("I’m so happy to be surrounded by amazing people.", "happy"),
                ("I feel anxious about the future and what it holds.", "anxious"),
                ("I’m really excited to make new memories.", "excited"),
                ("I feel stressed by all the things I need to do.", "stressed"),
                ("I feel disconnected from everyone around me.", "lonely"),
                ("I’m feeling so sad about everything that’s happened.", "sad"),
                ("I’m so happy that I’ve learned so much.", "happy"),
                ("I feel anxious about not being good enough.", "anxious"),
                ("I’m so excited for the possibilities ahead.", "excited"),
                ("I feel stressed by all the demands on my time.", "stressed"),
                ("I feel like no one really cares about me.", "lonely"),
                ("I’m feeling really sad after hearing that news.", "sad"),
                ("I’m so happy to have achieved something meaningful.", "happy"),
                ("I feel anxious about all the things I need to change.", "anxious"),
                ("I’m excited to see how things will turn out.", "excited"),
                ("I feel overwhelmed by everything that’s expected of me.", "stressed"),
                ("I feel completely alone in this situation.", "lonely"),
                ("I’m feeling down because things aren’t going well.", "sad"),
                ("I’m so happy to be where I am now.", "happy"),
                ("I’m anxious about how things will unfold.", "anxious"),
                ("I’m excited to make a change in my life.", "excited"),
                ("I feel stressed because there’s so much to do and so little time.", "stressed"),
                ("I feel like I have no real connections with anyone.", "lonely"),
                ("I’m feeling sad about how things have turned out.", "sad"),
                ("I’m so happy to be able to help others.", "happy"),
                ("I’m anxious about the unknown.", "anxious"),
                ("I’m really excited for the journey ahead.", "excited"),
                ("I feel stressed because I can’t keep up with everything.", "stressed"),
                ("I feel lonely even when I’m surrounded by people.", "lonely"),
                ("I’m feeling down after that conversation.", "sad"),
                ("I’m so happy to be able to spend time with my loved ones.", "happy"),
                ("I feel anxious about the upcoming presentation.", "anxious"),
                ("I’m so excited to start this new project.", "excited"),
                ("I’m feeling stressed because there’s too much to do.", "stressed"),
                ("I feel so lonely when I’m left out of plans.", "lonely"),
                ("I’m feeling sad that things didn’t work out the way I wanted.", "sad"),
                ("I’m so happy to have my friends by my side.", "happy"),
                ("I feel anxious about making mistakes.", "anxious"),
                ("I’m excited for the adventures that lie ahead.", "excited"),
                ("I feel stressed out with the pressure at work.", "stressed"),
                ("I feel isolated even though I’m surrounded by people.", "lonely"),
                ("I’m feeling down after receiving bad news.", "sad"),
                ("I’m so happy to see everyone happy around me.", "happy"),
                ("I feel anxious about the new changes happening in my life.", "anxious"),
                ("I’m really excited to meet new people.", "excited"),
                ("I feel stressed about my responsibilities at work.", "stressed"),
                ("I feel like I’m invisible to everyone.", "lonely"),
                ("I’m feeling sad that things are not going according to plan.", "sad"),
                ("I’m so happy to achieve this milestone.", "happy"),
                ("I feel anxious about not being prepared enough.", "anxious"),
                ("I’m excited to learn something new today.", "excited"),
                ("I feel stressed because I can’t seem to catch up.", "stressed"),
                ("I feel so lonely in this crowded place.", "lonely"),
                ("I’m feeling really sad about the situation.", "sad"),
                ("I’m so happy to finally be with my family.", "happy"),
                ("I feel anxious about dealing with this difficult task.", "anxious"),
                ("I’m excited to see how this turns out.", "excited"),
                ("I feel stressed with all the demands at work.", "stressed"),
                ("I feel disconnected from everyone around me.", "lonely"),
                ("I’m feeling down after a tough day.", "sad"),
                ("I’m so happy that everything is going well.", "happy"),
                ("I feel anxious about my future career.", "anxious"),
                ("I’m excited to start the weekend trip.", "excited"),
                ("I feel so stressed trying to meet all my deadlines.", "stressed"),
                ("I feel like I’m missing out on something important.", "lonely"),
                ("I’m feeling sad about how things turned out.", "sad"),
                ("I’m so happy to be making progress.", "happy"),
                ("I feel anxious about the decision I have to make.", "anxious"),
                ("I’m excited to discover new things in life.", "excited"),
                ("I feel stressed by the heavy workload I have.", "stressed"),
                ("I feel isolated and disconnected from everyone.", "lonely"),
                ("I’m feeling really sad today.", "sad"),
                ("I’m so happy to have accomplished something important.", "happy"),
                ("I feel anxious about the new responsibilities I have.", "anxious"),
                ("I’m excited to spend the day with my friends.", "excited"),
                ("I feel stressed because I have too many things on my mind.", "stressed"),
                ("I feel completely alone, even in a crowd.", "lonely"),
                ("I’m feeling sad about how things ended.", "sad"),
                ("I’m so happy to be surrounded by people who care.", "happy"),
                ("I feel anxious about making the wrong choice.", "anxious"),
                ("I’m excited to finally go on a vacation.", "excited"),
                ("I feel stressed about the upcoming exam.", "stressed"),
                ("I feel like no one understands what I’m going through.", "lonely"),
                ("I’m feeling really sad after losing something important.", "sad"),
                ("I’m so happy to see everything coming together.", "happy"),
                ("I feel anxious about the interview tomorrow.", "anxious"),
                ("I’m excited about the possibility of new opportunities.", "excited"),
                ("I feel so stressed with everything I have to do.", "stressed"),
                ("I feel disconnected from everyone around me.", "lonely"),
                ("I’m feeling down about how things are going in my life.", "sad"),
                ("I’m so happy to be where I am now.", "happy"),
                ("I feel anxious about the changes in my life.", "anxious"),
                ("I’m excited to experience something new.", "excited"),
                ("I feel stressed trying to balance work and life.", "stressed"),
                ("I feel like I don’t belong anywhere.", "lonely"),
                ("I’m feeling sad about missing an opportunity.", "sad"),
                ("I’m so happy to have achieved my goals.", "happy"),
                ("I feel anxious about not being prepared enough for the future.", "anxious"),
                ("I’m excited for the new challenges ahead.", "excited"),
                ("I feel so stressed about the expectations placed on me.", "stressed"),
                ("I feel alone in a crowded room.", "lonely"),
                ("I’m feeling sad after the breakup.", "sad"),
                ("I’m so happy that everything is falling into place.", "happy"),
                ("I feel anxious about dealing with difficult people.", "anxious"),
                ("I’m excited to learn and grow.", "excited"),
                ("I feel stressed by all the tasks I need to complete.", "stressed"),
                ("I feel like no one really cares about me.", "lonely"),
                ("I’m feeling really sad after losing someone close.", "sad"),
                ("I’m so happy to be able to enjoy life.", "happy"),
                ("I feel anxious about the uncertainty ahead.", "anxious"),
                ("I’m excited to see what the future holds.", "excited"),
                ("I feel stressed with everything going on in my life.", "stressed"),
                ("I feel like I’m always on my own.", "lonely"),
                ("I’m feeling sad about my current situation.", "sad"),
                ("I’m so happy to have made it through the tough times.", "happy"),
                ("I feel anxious about not meeting my goals.", "anxious"),
                ("I’m excited for what’s to come.", "excited"),
                ("I feel so stressed by everything going on at once.", "stressed"),
                ("I feel disconnected from the people around me.", "lonely"),
                ("I’m feeling down after a bad day.", "sad"),
                ("I’m so happy to be in a better place now.", "happy"),
                ("I feel anxious about taking on more work.", "anxious"),
                ("I’m excited to begin a new chapter in my life.", "excited"),
                ("I feel stressed by the pressure to succeed.", "stressed"),
                ("I feel like no one understands what I’m going through.", "lonely"),
                ("I’m feeling sad after hearing that news.", "sad"),
                ("I’m so happy to be in a place I love.", "happy"),
                ("I feel anxious about the unknown future.", "anxious"),
                ("I’m excited for the future and the possibilities it holds.", "excited"),
                ("I feel stressed by the constant demands of life.", "stressed"),
                ("I feel alone in a crowd of people.", "lonely"),
                ("I’m feeling sad because things aren’t going my way.", "sad"),
                ("I’m so happy to have made progress.", "happy"),
                ("I feel anxious about what tomorrow might bring.", "anxious"),
                ("I’m excited for all the new things I’ll experience.", "excited"),
                ("I feel stressed because I’m falling behind.", "stressed"),
                ("I feel completely alone in this journey.", "lonely"),
                ("I’m feeling down about my situation.", "sad"),
                ("I’m so happy to be able to relax for a moment.", "happy"),
                ("I feel anxious about the pressure to do well.", "anxious"),
                ("I’m excited to spend time with my loved ones.", "excited"),
                ("I feel stressed because everything feels like it’s falling apart.", "stressed"),
                ("I feel lonely even though I’m surrounded by people.", "lonely"),
                ("I’m feeling sad about everything falling apart.", "sad"),
                ("I’m so happy that everything is finally working out.", "happy"),
                ("I feel anxious about the challenges ahead.", "anxious"),
                ("I’m excited for what’s next in my life.", "excited"),
                ("I feel stressed trying to juggle so many things at once.", "stressed"),
                ("I feel disconnected from my friends.", "lonely"),
                ("I’m feeling really sad after that argument.", "sad"),
                ("I’m so happy to be living in the moment.", "happy"),
                ("I feel anxious about the consequences of my actions.", "anxious"),
                ("I’m excited for the change in my life.", "excited"),
                ("I feel stressed about the responsibilities I have.", "stressed"),
                ("I feel alone in this world.", "lonely"),
                ("I’m feeling really sad about how things turned out.", "sad")

]

df = pd.DataFrame(data, columns=["Text", "Emotion"])
print(df.head())
# Out:
#                               Text   Emotion
# 0   I'm feeling really down today.       sad
# 1       I just got some good news!     happy
# 2      I'm feeling really anxious.   anxious
# 3  I’m excited about this weekend!   excited
# 4   I'm so stressed out with work.  stressed

# %%
import shutil
import nltk

# Remove old NLTK data
nltk_data_path = nltk.data.path[0]
shutil.rmtree(nltk_data_path, ignore_errors=True)

# Re-download the necessary resources
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import nltk
print(nltk.data.path)
# Out:
# ['/usr/local/nltk_data', '/root/nltk_data']

# %%
nltk.data.path = ['/usr/local/nltk_data', '/root/nltk_data']
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import shutil
import nltk

# Remove stopwords corpus
stopwords_path = '/root/nltk_data/corpora/stopwords'
shutil.rmtree(stopwords_path, ignore_errors=True)

# Re-download the stopwords corpus
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
import re

def preprocess(text):
    # Lowercase the text
    text = text.lower()

    # Remove non-alphanumeric characters (punctuation)
    text = re.sub(r'[^a-z0-9\s]', '', text)

    # Tokenize by splitting the text into words
    tokens = text.split()

    # Remove stopwords
    tokens = [word for word in tokens if word not in ENGLISH_STOP_WORDS]

    return " ".join(tokens)

df['Processed_Text'] = df['Text'].apply(preprocess)

# %%
X_train, X_test, y_train, y_test = train_test_split(df['Processed_Text'], df['Emotion'], test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()
model = MultinomialNB()

pipeline = make_pipeline(vectorizer, model)
pipeline.fit(X_train, y_train)

y_pred = pipeline.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#      anxious       0.92      1.00      0.96        23
#    energized       0.00      0.00      0.00         1
#      excited       1.00      1.00      1.00        23
#     grateful       0.00      0.00      0.00         1
#        happy       0.85      1.00      0.92        28
#      hopeful       0.00      0.00      0.00         1
#       lonely       0.83      0.96      0.89        25
#         lost       0.00      0.00      0.00         1
#    motivated       0.00      0.00      0.00         1
#      neutral       1.00      0.38      0.55         8
#     positive       0.00      0.00      0.00         1
#        proud       0.00      0.00      0.00         4
#          sad       0.86      0.94      0.90        32
#     stressed       0.75      0.86      0.80        21
#        stuck       0.00      0.00      0.00         1
#    uncertain       0.00      0.00      0.00         1
#
# ...
